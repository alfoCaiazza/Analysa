# %%
import pandas as pd
import torch
import numpy as np
import tqdm
from bertopic import BERTopic

# %% [markdown]
# ### Global topic Modeling Task - Analysing each commmunity globally

# %%
text_df = pd.read_csv('../../../src/nlp/cleaned_dataset.csv')
community_df = pd.read_csv('../../../src/data/distribuitions/hub_bridge_df.csv')

# %%
merged_df = text_df.merge(community_df, left_on='author', right_on='id', how='inner')

# Community grouping and text aggregation
community_texts = (
    merged_df.groupby('community_id')['clean_text'].apply(list) #getting texts list
    .reset_index()
)

# Alternativelly for a string
# .apply(lambda x: " ".join(x))

# %%
community_texts
# Out:
#     community_id                                         clean_text
# 0            0.0  [trump announced new weapons ukraine monday th...
# 1            1.0  [trump doge making massive cuts federal workfo...
# 2            2.0  [every friday posts withheld review moderators...
# 3            3.0  [terrorist defined person uses unlawful violen...
# 4            4.0  [usually hears controlled opposition it s rega...
# ..           ...                                                ...
# 73          73.0  [point 2 say reddit prides open discourse howe...
# 74          74.0  [ok disney hot hectic exhausting often unneces...
# 75          75.0  [point four say something anything rapist jail...
# 76          76.0  [nta complaining ready step pay additional ser...
# 77          77.0  [yta occupying living room television mil visi...
#
# [78 rows x 2 columns]

# %%
community_0 = merged_df.loc[merged_df['community_id'] == 0.0]
community_0['clean_text'] = community_0['clean_text'].astype(str)

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(community_0['clean_text'].tolist())
# Out:
# /home/acaia/Analysa/Analysa/.analysa/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                              Name  \
# 0       -1  12576                            -1_trump_us_right_iran
# 1        0    393     0_moderate_progressive_progressives_democrats
# 2        1    319              1_tariffs_trade_tariff_manufacturing
# 3        2    307                        2_tax_taxes_income_federal
# 4        3    301                            3_thanks_thank_ok_yeah
# ..     ...    ...                                               ...
# 241    240     11  240_economists_economics_monopolies_askeconomics
# 242    241     11                   241_contempt_court_comply_order
# 243    242     10                     242_regime_change_split_south
# 244    243     10                 243_plan_cbo_civically_peoplemwho
# 245    244     10              244_happiness_pursuit_consent_powers
#
#                                         Representation  \
# 0    [trump, us, right, iran, going, way, party, mu...
# 1    [moderate, progressive, progressives, democrat...
# 2    [tariffs, trade, tariff, manufacturing, countr...
# 3    [tax, taxes, income, federal, rate, pay, rates...
# 4    [thanks, thank, ok, yeah, okay, oh, question, ...
# ..                                                 ...
# 241  [economists, economics, monopolies, askeconomi...
# 242  [contempt, court, comply, order, jail, ordered...
# 243  [regime, change, split, south, diem, holland, ...
# 244  [plan, cbo, civically, peoplemwho, pf, sellout...
# 245  [happiness, pursuit, consent, powers, despotis...
#
#                                    Representative_Docs
# 0    [immigration enforcement driving wages goal tr...
# 1    [wrote somewhere else yes lot progressive poli...
# 2    [reciprocal tariffs often lead tariffs countri...
# 3    [can t eliminate deficit level taxation rich f...
# 4    [interesting thank, ok gotcha thanks, yeah thi...
# ..                                                 ...
# 241  [economists glorified tarot card readers say e...
# 242  [shit post article states administration cited...
# 243  [question practical strategic peaceful steps m...
# 244  [peoplemwho know away shit rewarding friends e...
# 245  [already really hope understand implications t...
#
# [246 rows x 5 columns]

# %%
topic_model.get_topic(-1)
# Out:
# [('trump', np.float64(0.0038465007919400466)),
#  ('us', np.float64(0.0031451766527744282)),
#  ('right', np.float64(0.003023903134446666)),
#  ('iran', np.float64(0.0029418798153620055)),
#  ('going', np.float64(0.0026531606211747144)),
#  ('way', np.float64(0.0026448898537439315)),
#  ('party', np.float64(0.0026392663035120006)),
#  ('much', np.float64(0.002616948610481152)),
#  ('make', np.float64(0.0025407126947250723)),
#  ('know', np.float64(0.002537601302137159))]
